# %% [markdown]
# <h1 style="color:rgb(17, 116, 155);text-align:left;font-size:250%;font-family:verdana;text-decoration:underline;">
#     Advanced topics - Final Project - Part 3: End-to-End CNN</h1>

# %% [markdown]
# ## <u>Imports</u>

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from PIL import Image, ImageFilter
import tensorflow as tf
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import time
import torch.nn.functional as F
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
import torchvision.models as models
import gc

# %%
# קביעת התקן (GPU אם קיים)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
torch.cuda.empty_cache()  # אם יש GPU 
gc.collect()  # ניקוי זיכרון בפייתון
# Out:
# 183

# %% [markdown]
# ## <u>Load and Preprocess Dataset</u>

# %%
# טעינת הנתונים (TFRecord) והכנה לפורמט PyTorch
print("Loading Cars196 dataset from TFRecord files...")

data_dir = r"C:\Users\yifat\Data Science\נושאים מתקדמים\Final_Project_Shay\cars196"

# יצירת רשימת קבצי ה-TFRecord
train_files = [os.path.join(data_dir, f"cars196-train.tfrecord-0000{i}-of-00008") for i in range(8)]
test_files = [os.path.join(data_dir, f"cars196-test.tfrecord-0000{i}-of-00008") for i in range(8)]

# פונקציה לקריאת TFRecord
def parse_tfrecord(example):
    feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'label': tf.io.FixedLenFeature([], tf.int64)
    }
    parsed_example = tf.io.parse_single_example(example, feature_description)
    
    image = tf.image.decode_jpeg(parsed_example['image'], channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)  # מונע איבוד מידע
    image = tf.image.resize(image, (224, 224))

    label = parsed_example['label']
    return image, label


def load_tfrecord_dataset(filenames):
    raw_dataset = tf.data.TFRecordDataset(filenames)
    dataset = raw_dataset.map(parse_tfrecord)
    return list(dataset)  # ממירים לרשימה לשימוש ב-PyTorch

# טעינת ה-Train/Test מ-TFRecord
train_data = [(image, label) for image, label in load_tfrecord_dataset(train_files)]
test_data = [(image, label) for image, label in load_tfrecord_dataset(test_files)]


print(f"Loaded {len(train_data)} training images and {len(test_data)} test images.")
# Out:
# Loading Cars196 dataset from TFRecord files...
# Loaded 8144 training images and 8041 test images.

# %%
# מחלקת Dataset לטעינת הנתונים
class Cars196Dataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_tf, label = self.data[idx]  # image_tf הוא Tensor של TensorFlow
        image_np = image_tf.numpy()  # המרה ל-NumPy
        image = Image.fromarray((image_np * 255).astype(np.uint8))  # הבאת הפיקסלים לטווח 0-255
        if self.transform:
            image = self.transform(image)
        return image, label.numpy()  # גם label צריך להיות מספר ולא Tensor

# %%
# ניסיון עם אוגמנטציה פחות אגרסיבית
# הפחתת רמת ה-ColorJitter והאוגמנטציות הגורמות לעיוותים גדולים כמו RandomPerspective ו-RandomAffine
# הימנעות מיותר מדי RandomErasing, שכן זה יכול לגרום לאיבוד מידע חשוב
############################################################

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.RandomHorizontalFlip(p=0.5),  # היפוך אופקי
    transforms.RandomRotation(10),  # הקטנת סיבוב ל-10 מעלות
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),  # הקטנת שינויי הצבעים
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # פחות חיתוך
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# סט הבדיקה ללא אוגמנטציה
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
batch_size = 4
train_dataset = Cars196Dataset(train_data, transform=train_transform)
test_dataset = Cars196Dataset(test_data, transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

print(f"Train and Test Dataloaders created with batch size {batch_size}.")
print(f"Training samples: {len(train_dataset)}, Testing samples: {len(test_dataset)}")
# Out:
# Train and Test Dataloaders created with batch size 4.
# Training samples: 8144, Testing samples: 8041

# %%
# חישוב משקלים למחלקות לטיפול בחוסר איזון
labels_list = np.array([label.numpy() for _, label in train_data])  # המרה ל-NumPy
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels_list), y=labels_list)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)  # המרה ל-Tensor של PyTorch

# %% [markdown]
# ## <u>Define and Train a CNN Model</u>

# %%
# הוספת שכבות קונבולוציה כדי להגדיל את עומק הרשת
# Batch Normalization לאחר כל שכבת קונבולוציה כדי לסייע ללמידה יציבה יותר
# הגדלת מספר הנוירונים בשכבות ה-FC

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=196):
        super(CNNClassifier, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(512)

        self.pool = nn.AdaptiveAvgPool2d((1,1))  # ממוצע לכל התמונה
        self.dropout = nn.Dropout(0.5)

        self.fc1 = nn.Linear(512, 256)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# יצירת המודל
model = CNNClassifier(num_classes=196).to(device)

# בדיקה האם המודל נטען ל-GPU או לא
print(f"Model is running on: {next(model.parameters()).device}")

# הגדרת פונקציית הפסד ואופטימיזציה
num_epochs = 1  # הגדלת מספר האפוקים

# פונקציית הפסד: שימוש בשקלול מחלקות בלבד
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)  # שינוי מ-SGD ל-AdamW
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.005, steps_per_epoch=len(train_loader), epochs=num_epochs)
# Out:
# Model is running on: cuda:0

# %%
print(torch.cuda.is_available())  # צריך להחזיר True
print(torch.cuda.device_count())  # צריך להיות 1 לפחות
print(torch.cuda.get_device_name(0))  # שם הכרטיס הגרפי
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
torch.cuda.empty_cache()  # אם יש GPU 
gc.collect()  # ניקוי זיכרון בפייתון
# Out:
# 543

# %%
# פונקציות אימון ובדיקה
def train_epoch(model, train_loader, criterion, optimizer):
    model.train()
    model.to(device)
    running_loss = 0
    start_time = time.time()

    for batch_idx, (images, labels) in enumerate(train_loader):  # הוספנו batch_idx
        print(f"Processing batch {batch_idx+1}/{len(train_loader)}")  # הדפסה כדי לעקוב אחר ההתקדמות
    #for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    scheduler.step()  # עדכון הלרנינג רייט בסוף כל אפוק
    end_time = time.time()
    running_loss /= len(train_loader)
    return running_loss, end_time - start_time
    

# פונקציה לבדיקה של המודל
def test_model(model, test_loader, criterion):
    with torch.no_grad():
        model.eval()
        model.to(device)
        running_loss = 0
        total_predictions = 0
        correct_predictions = 0
        
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()
        
        running_loss /= len(test_loader)
        accuracy = (correct_predictions / total_predictions)*100.0
        return running_loss, accuracy

# %%
# שילוב Early Stopping 
######################

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.001):
        """
        patience - מספר האפוקים ללא שיפור לפני עצירה
        min_delta - השיפור המינימלי שייחשב לשיפור אמיתי
        """
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0  # אפס את הספירה אם יש שיפור
        else:
            self.counter += 1  # ספירה של אפוקים ללא שיפור

        return self.counter >= self.patience  # עצור אם חרגנו ממספר האפוקים המותר

# %%
# אימון הרשת
early_stopping = EarlyStopping(patience=10, min_delta=0.001)  # עצירה אחרי 10 אפוקים ללא שיפור

num_epochs = 1  # הגדלת מספר האפוקים

for epoch in range(num_epochs):
    print(f"Starting epoch {epoch+1}/{num_epochs}...")
    #torch.cuda.empty_cache()
    #gc.collect()

    train_loss, train_time = train_epoch(model, train_loader, criterion, optimizer)
    test_loss, test_acc = test_model(model, test_loader, criterion)

    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss = {train_loss:.6f}, Time = {train_time:.2f}s")
    print(f"Test Loss = {test_loss:.6f}, Accuracy = {test_acc:.2f}%")
    print('-' * 60)

    if early_stopping(test_loss):
        print(f"Early stopping at epoch {epoch+1}")
        break


# לאחר הלולאה:
del model
torch.cuda.empty_cache()
gc.collect()
print("Model deleted and GPU memory cleared.")

# שמירת המודל
torch.save(model.state_dict(), "cars196_cnn_trained.pth")
print("End-to-End CNN model training completed and saved!")
# Out:
# Starting epoch 1/1...
# Processing batch 1/2036
# Processing batch 2/2036
# Processing batch 3/2036
# Processing batch 4/2036
# Processing batch 5/2036
# Processing batch 6/2036
# Processing batch 7/2036
# Processing batch 8/2036
# Processing batch 9/2036
# Processing batch 10/2036
# Processing batch 11/2036
# Processing batch 12/2036
# Processing batch 13/2036
# Processing batch 14/2036
# Processing batch 15/2036
# Processing batch 16/2036
# Processing batch 17/2036
# Processing batch 18/2036
# Processing batch 19/2036
# Processing batch 20/2036
# Processing batch 21/2036
# Processing batch 22/2036
# Processing batch 23/2036
# Processing batch 24/2036
# Processing batch 25/2036
# Processing batch 26/2036
# Processing batch 27/2036
# Processing batch 28/2036
# Processing batch 29/2036
# Processing batch 30/2036
# Processing batch 31/2036
# Processing batch 32/2036
# Processing batch 33/2036
# Processing batch 34/2036
# Processing batch 35/2036
# Processing batch 36/2036
# Processing batch 37/2036
# Processing batch 38/2036
# Processing batch 39/2036
# Processing batch 40/2036
# Processing batch 41/2036
# Processing batch 42/2036
# Processing batch 43/2036
# Processing batch 44/2036
# Processing batch 45/2036
# Processing batch 46/2036
# Processing batch 47/2036
# Processing batch 48/2036
# Processing batch 49/2036
# Processing batch 50/2036
# Processing batch 51/2036
# Processing batch 52/2036
# Processing batch 53/2036
# Processing batch 54/2036
# Processing batch 55/2036
# Processing batch 56/2036
# Processing batch 57/2036
# Processing batch 58/2036
# Processing batch 59/2036
# Processing batch 60/2036
# Processing batch 61/2036
# Processing batch 62/2036
# Processing batch 63/2036
# Processing batch 64/2036
# Processing batch 65/2036
# Processing batch 66/2036
# Processing batch 67/2036
# Processing batch 68/2036
# Processing batch 69/2036
# Processing batch 70/2036
# Processing batch 71/2036
# Processing batch 72/2036
# Processing batch 73/2036
# Processing batch 74/2036
# Processing batch 75/2036
# Processing batch 76/2036
# Processing batch 1933/2036
# Processing batch 1934/2036
# Processing batch 1935/2036
# Processing batch 1936/2036
# Processing batch 1937/2036
# Processing batch 1938/2036
# Processing batch 1939/2036
# Processing batch 1940/2036
# Processing batch 1941/2036
# Processing batch 1942/2036
# Processing batch 1943/2036
# Processing batch 1944/2036
# Processing batch 1945/2036
# Processing batch 1946/2036
# Processing batch 1947/2036
# Processing batch 1948/2036
# Processing batch 1949/2036
# Processing batch 1950/2036
# Processing batch 1951/2036
# Processing batch 1952/2036
# Processing batch 1953/2036
# Processing batch 1954/2036
# Processing batch 1955/2036
# Processing batch 1956/2036
# Processing batch 1957/2036
# Processing batch 1958/2036
# Processing batch 1959/2036
# Processing batch 1960/2036
# Processing batch 1961/2036
# Processing batch 1962/2036
# Processing batch 1963/2036
# Processing batch 1964/2036
# Processing batch 1965/2036
# Processing batch 1966/2036
# Processing batch 1967/2036
# Processing batch 1968/2036
# Processing batch 1969/2036
# Processing batch 1970/2036
# Processing batch 1971/2036
# Processing batch 1972/2036
# Processing batch 1973/2036
# Processing batch 1974/2036
# Processing batch 1975/2036
# Processing batch 1976/2036
# Processing batch 1977/2036
# Processing batch 1978/2036
# Processing batch 1979/2036
# Processing batch 1980/2036
# Processing batch 1981/2036
# Processing batch 1982/2036
# Processing batch 1983/2036
# Processing batch 1984/2036
# Processing batch 1985/2036
# Processing batch 1986/2036
# Processing batch 1987/2036
# Processing batch 1988/2036
# Processing batch 1989/2036
# Processing batch 1990/2036
# Processing batch 1991/2036
# Processing batch 1992/2036
# Processing batch 1993/2036
# Processing batch 1994/2036
# Processing batch 1995/2036
# Processing batch 1996/2036
# Processing batch 1997/2036
# Processing batch 1998/2036
# Processing batch 1999/2036
# Processing batch 2000/2036
# Processing batch 2001/2036
# Processing batch 2002/2036
# Processing batch 2003/2036
# Processing batch 2004/2036
# Processing batch 2005/2036
# Processing batch 2006/2036
# Processing batch 2007/2036
# Processing batch 2008/2036
# Processing batch 2009/2036
# Processing batch 2010/2036
# Processing batch 2011/2036
# Processing batch 2012/2036
# Processing batch 2013/2036
# Processing batch 2014/2036
# Processing batch 2015/2036
# Processing batch 2016/2036
# Processing batch 2017/2036
# Processing batch 2018/2036
# Processing batch 2019/2036
# Processing batch 2020/2036
# Processing batch 2021/2036
# Processing batch 2022/2036
# Processing batch 2023/2036
# Processing batch 2024/2036
# Processing batch 2025/2036
# Processing batch 2026/2036
# Processing batch 2027/2036
# Processing batch 2028/2036
# Processing batch 2029/2036
# Processing batch 2030/2036
# Processing batch 2031/2036
# Processing batch 2032/2036
# Processing batch 2033/2036
# Processing batch 2034/2036
# Processing batch 2035/2036
# Processing batch 2036/2036
# Epoch 1/1: Train Loss = 5.282606, Time = 653.39s
# Test Loss = 5.239027, Accuracy = 0.86%
# ------------------------------------------------------------
# Model deleted and GPU memory cleared.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 30
#      27 print("Model deleted and GPU memory cleared.")
#      29 # שמירת המודל
# ---> 30 torch.save(model.state_dict(), "cars196_cnn_trained.pth")
#      31 print("End-to-End CNN model training completed and saved!")
#
# NameError: name 'model' is not defined
