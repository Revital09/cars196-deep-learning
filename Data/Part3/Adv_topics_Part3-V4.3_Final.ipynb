# %% [markdown]
# <h1 style="color:rgb(17, 116, 155);text-align:left;font-size:250%;font-family:verdana;text-decoration:underline;">
#     Advanced topics - Final Project - Part 3: End-to-End CNN</h1>

# %% [markdown]
# ## <u>Imports</u>

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from PIL import Image, ImageFilter
import tensorflow as tf
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import time
import torch.nn.functional as F
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
import gc

# %%
# קביעת התקן (GPU אם קיים)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
torch.cuda.empty_cache()  # אם יש GPU 
gc.collect()  # ניקוי זיכרון בפייתון
# Out:
# 178

# %% [markdown]
# ## <u>Load and Preprocess Dataset</u>

# %%
# טעינת הנתונים (TFRecord) והכנה לפורמט PyTorch
print("Loading Cars196 dataset from TFRecord files...")

data_dir = r"C:\Users\yifat\Data Science\נושאים מתקדמים\Final_Project_Shay\cars196"

# יצירת רשימת קבצי ה-TFRecord
train_files = [os.path.join(data_dir, f"cars196-train.tfrecord-0000{i}-of-00008") for i in range(8)]
test_files = [os.path.join(data_dir, f"cars196-test.tfrecord-0000{i}-of-00008") for i in range(8)]

# פונקציה לקריאת TFRecord
def parse_tfrecord(example):
    feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'label': tf.io.FixedLenFeature([], tf.int64)
    }
    parsed_example = tf.io.parse_single_example(example, feature_description) # פענח דוגמה אחת מתוך קובץ TFRecord לפי המבנה
    
    image = tf.image.decode_jpeg(parsed_example['image'], channels=3) # ממיר את המחרוזת של התמונה לביטים של RGB
    image = tf.image.convert_image_dtype(image, tf.float32)  # מונע איבוד מידע, ממיר את התמונה לערכים בטווח [0,1]
    image = tf.image.resize(image, (224, 224))

    label = parsed_example['label']
    return image, label


def load_tfrecord_dataset(filenames):
    raw_dataset = tf.data.TFRecordDataset(filenames)
    dataset = raw_dataset.map(parse_tfrecord)
    return list(dataset)  # ממירים לרשימה לשימוש ב-PyTorch

# טעינת ה-Train/Test מ-TFRecord
train_data = [(image, label) for image, label in load_tfrecord_dataset(train_files)]
test_data = [(image, label) for image, label in load_tfrecord_dataset(test_files)]


print(f"Loaded {len(train_data)} training images and {len(test_data)} test images.")
# Out:
# Loading Cars196 dataset from TFRecord files...
# Loaded 8144 training images and 8041 test images.

# %%
# מחלקת Dataset לטעינת הנתונים
class Cars196Dataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_tf, label = self.data[idx]  # image_tf הוא Tensor של TensorFlow
        image_np = image_tf.numpy()  # המרה ל-NumPy
        image = Image.fromarray((image_np * 255).astype(np.uint8))  # הבאת הפיקסלים לטווח 0-255
        if self.transform:
            image = self.transform(image)
        return image, label.numpy()  # גם label צריך להיות מספר ולא Tensor

# %%
# ניסיון עם אוגמנטציה פחות אגרסיבית
# הפחתת רמת ה-ColorJitter והאוגמנטציות הגורמות לעיוותים גדולים כמו RandomPerspective ו-RandomAffine
# הימנעות מיותר מדי RandomErasing, שכן זה יכול לגרום לאיבוד מידע חשוב
############################################################

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.RandomHorizontalFlip(p=0.5),  # היפוך אופקי
    transforms.RandomRotation(10),  # הקטנת סיבוב ל-10 מעלות
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),  # הקטנת שינויי הצבעים
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # פחות חיתוך
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# סט הבדיקה ללא אוגמנטציה
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
batch_size = 32
train_dataset = Cars196Dataset(train_data, transform=train_transform)
test_dataset = Cars196Dataset(test_data, transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

print(f"Train and Test Dataloaders created with batch size {batch_size}.")
print(f"Training samples: {len(train_dataset)}, Testing samples: {len(test_dataset)}")
# Out:
# Train and Test Dataloaders created with batch size 32.
# Training samples: 8144, Testing samples: 8041

# %% [raw]
# # חישוב משקלים למחלקות לטיפול בחוסר איזון
# labels_list = [label for _, label in train_data]
# class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels_list), y=labels_list)
# class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
#
# # פונקציית הפסד משופרת: שימוש ב-Focal Loss
# class FocalLoss(nn.Module):
#     def __init__(self, alpha=0.25, gamma=1):  # שימוש בערכים קבועים
#         super(FocalLoss, self).__init__()
#         self.alpha = alpha
#         self.gamma = gamma
#         self.ce_loss = nn.CrossEntropyLoss()
#
#     def forward(self, inputs, targets):
#         ce_loss = self.ce_loss(inputs, targets)
#         p_t = torch.exp(-ce_loss)
#         focal_loss = self.alpha * (1 - p_t) ** self.gamma * ce_loss
#         return focal_loss.mean()

# %%
# חישוב משקלים למחלקות לטיפול בחוסר איזון
labels_list = np.array([label.numpy() for _, label in train_data])  # המרה ל-NumPy
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels_list), y=labels_list)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)  # המרה ל-Tensor של PyTorch

# %% [markdown]
# ## <u>Define and Train a CNN Model</u>

# %%
# הוספת שכבות קונבולוציה כדי להגדיל את עומק הרשת
# Batch Normalization לאחר כל שכבת קונבולוציה כדי לסייע ללמידה יציבה יותר
# הגדלת מספר הנוירונים בשכבות ה-FC

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=196):
        super(CNNClassifier, self).__init__()

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)  # הוספת נורמליזציה
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(512)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.dropout = nn.Dropout(0.5)

        self.fc1 = nn.Linear(512 * 14 * 14, 2048)  # הגדלת מספר הנוירונים
        self.fc2 = nn.Linear(2048, 1024)
        self.fc3 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = self.pool(F.relu(self.bn4(self.conv4(x))))

        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x

# %% [raw]
# # יצירת המודל
# model = CNNClassifier(num_classes=196).to(device)
#
# # הגדרת פונקציית הפסד ואופטימיזציה
# #criterion = nn.CrossEntropyLoss()
# #optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)
#
# ###############################
# # ניסיון 2
# ###############################
# # הגדרת פונקציית הפסד ואופטימיזציה
# num_epochs = 100  # הגדלת מספר האפוקים
#
# criterion = FocalLoss()  # שימוש ב-Focal Loss
# optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)  # שינוי מ-SGD ל-AdamW
# #scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # הפחתת הלמידה כל 5 אפוקים
# # שימוש ב- OneCycleLR במקום StepLR, כך שהמודל יתאים את הלמידה לאורך הזמן
# scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.005, steps_per_epoch=len(train_loader), epochs=num_epochs)

# %%
# יצירת המודל
model = CNNClassifier(num_classes=196).to(device)

# בדיקה האם המודל נטען ל-GPU או לא
print(f"Model is running on: {next(model.parameters()).device}")

# הגדרת פונקציית הפסד ואופטימיזציה
num_epochs = 100  # הגדלת מספר האפוקים

# פונקציית הפסד: שימוש בשקלול מחלקות בלבד
criterion = nn.CrossEntropyLoss(weight=class_weights)

# AdamW -גרסה משופרת של Adam שמוסיפה רגולריזציה (weight_decay) כדי למנוע overfitting
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)  # שינוי מ-SGD ל-AdamW
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.005, steps_per_epoch=len(train_loader), epochs=num_epochs)
# Out:
# Model is running on: cuda:0

# %%
print(torch.cuda.is_available())  # צריך להחזיר True
print(torch.cuda.device_count())  # צריך להיות 1 לפחות
print(torch.cuda.get_device_name(0))  # שם הכרטיס הגרפי

torch.cuda.empty_cache()  # אם יש GPU 
gc.collect()  # ניקוי זיכרון בפייתון
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU
# 543

# %%
# פונקציות אימון ובדיקה
def train_epoch(model, train_loader, criterion, optimizer):
    model.train()
    model.to(device)
    running_loss = 0
    start_time = time.time()
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    scheduler.step()  # עדכון הלרנינג רייט בסוף כל אפוק
    end_time = time.time()
    running_loss /= len(train_loader)
    return running_loss, end_time - start_time
    

# פונקציה לבדיקה של המודל
def test_model(model, test_loader, criterion):
    with torch.no_grad():
        model.eval()
        model.to(device)
        running_loss = 0
        total_predictions = 0
        correct_predictions = 0
        
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()
        
        running_loss /= len(test_loader)
        accuracy = (correct_predictions / total_predictions)*100.0
        return running_loss, accuracy

# %%
# שילוב Early Stopping 
######################

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.001):
        """
        patience - מספר האפוקים ללא שיפור לפני עצירה
        min_delta - השיפור המינימלי שייחשב לשיפור אמיתי
        """
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0  # אפס את הספירה אם יש שיפור
        else:
            self.counter += 1  # ספירה של אפוקים ללא שיפור

        return self.counter >= self.patience  # עצור אם חרגנו ממספר האפוקים המותר

# %%
# אימון הרשת
early_stopping = EarlyStopping(patience=10, min_delta=0.001)  # עצירה אחרי 10 אפוקים ללא שיפור

num_epochs = 100  # הגדלת מספר האפוקים

for epoch in range(num_epochs):
    train_loss, train_time = train_epoch(model, train_loader, criterion, optimizer)
    test_loss, test_acc = test_model(model, test_loader, criterion)

    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss = {train_loss:.6f}, Time = {train_time:.2f}s")
    print(f"Test Loss = {test_loss:.6f}, Accuracy = {test_acc:.2f}%")
    print('-' * 60)

    if early_stopping(test_loss):  # בדיקה אם צריך לעצור
        print(f"Early stopping at epoch {epoch+1}")
        break


# שמירת המודל
torch.save(model.state_dict(), "cars196_cnn_trained.pth")
print("End-to-End CNN model training completed and saved!")

# ניקוי מהזיכרון
del model
torch.cuda.empty_cache()
gc.collect()
print("Model deleted and GPU memory cleared.")
# Out:
# Epoch 1/100: Train Loss = 5.516137, Time = 370.12s
# Test Loss = 5.216043, Accuracy = 0.86%
# ------------------------------------------------------------
# Epoch 2/100: Train Loss = 5.220843, Time = 296.34s
# Test Loss = 5.181381, Accuracy = 1.12%
# ------------------------------------------------------------
# Epoch 3/100: Train Loss = 5.201570, Time = 295.74s
# Test Loss = 5.181081, Accuracy = 1.22%
# ------------------------------------------------------------
# Epoch 4/100: Train Loss = 5.188824, Time = 294.58s
# Test Loss = 5.156318, Accuracy = 1.44%
# ------------------------------------------------------------
# Epoch 5/100: Train Loss = 5.172053, Time = 297.02s
# Test Loss = 5.151385, Accuracy = 1.39%
# ------------------------------------------------------------
# Epoch 6/100: Train Loss = 5.154747, Time = 295.27s
# Test Loss = 5.129908, Accuracy = 1.95%
# ------------------------------------------------------------
# Epoch 7/100: Train Loss = 5.148698, Time = 294.64s
# Test Loss = 5.127864, Accuracy = 1.63%
# ------------------------------------------------------------
# Epoch 8/100: Train Loss = 5.138226, Time = 295.86s
# Test Loss = 5.120056, Accuracy = 1.78%
# ------------------------------------------------------------
# Epoch 9/100: Train Loss = 5.123594, Time = 295.36s
# Test Loss = 5.132287, Accuracy = 1.73%
# ------------------------------------------------------------
# Epoch 10/100: Train Loss = 5.103155, Time = 295.89s
# Test Loss = 5.101868, Accuracy = 1.99%
# ------------------------------------------------------------
# Epoch 11/100: Train Loss = 5.098845, Time = 295.44s
# Test Loss = 5.086971, Accuracy = 1.93%
# ------------------------------------------------------------
# Epoch 57/100: Train Loss = 4.040730, Time = 296.32s
# Test Loss = 4.289304, Accuracy = 8.39%
# ------------------------------------------------------------
# Epoch 58/100: Train Loss = 4.006810, Time = 296.61s
# Test Loss = 4.386242, Accuracy = 7.93%
# ------------------------------------------------------------
# Epoch 59/100: Train Loss = 3.992600, Time = 296.63s
# Test Loss = 4.383516, Accuracy = 7.85%
# ------------------------------------------------------------
# Epoch 60/100: Train Loss = 3.964547, Time = 296.75s
# Test Loss = 4.212005, Accuracy = 9.35%
# ------------------------------------------------------------
# Epoch 61/100: Train Loss = 3.936481, Time = 296.89s
# Test Loss = 4.274632, Accuracy = 8.82%
# ------------------------------------------------------------
# Epoch 62/100: Train Loss = 3.930597, Time = 296.49s
# Test Loss = 4.170876, Accuracy = 9.73%
# ------------------------------------------------------------
# Epoch 63/100: Train Loss = 3.904537, Time = 297.40s
# Test Loss = 4.190266, Accuracy = 9.63%
# ------------------------------------------------------------
# Epoch 64/100: Train Loss = 3.852020, Time = 296.73s
# Test Loss = 4.148544, Accuracy = 9.86%
# ------------------------------------------------------------
# Epoch 65/100: Train Loss = 3.858393, Time = 296.85s
# Test Loss = 4.146720, Accuracy = 10.48%
# ------------------------------------------------------------
# Epoch 66/100: Train Loss = 3.816685, Time = 296.51s
# Test Loss = 4.158099, Accuracy = 9.51%
# ------------------------------------------------------------
# Epoch 67/100: Train Loss = 3.787745, Time = 296.36s
# Test Loss = 4.118577, Accuracy = 10.56%
# ------------------------------------------------------------
# Epoch 68/100: Train Loss = 3.784291, Time = 296.64s
# Test Loss = 4.092480, Accuracy = 10.97%
# ------------------------------------------------------------
# Epoch 69/100: Train Loss = 3.731768, Time = 296.11s
# Test Loss = 4.102861, Accuracy = 10.07%
# ------------------------------------------------------------
# Epoch 70/100: Train Loss = 3.749426, Time = 297.22s
# Test Loss = 4.096241, Accuracy = 10.33%
# ------------------------------------------------------------
# Epoch 71/100: Train Loss = 3.700891, Time = 296.97s
# Test Loss = 4.080820, Accuracy = 10.56%
# ------------------------------------------------------------
# Epoch 72/100: Train Loss = 3.668892, Time = 297.74s
# Test Loss = 4.099928, Accuracy = 10.61%
# ------------------------------------------------------------
# Epoch 73/100: Train Loss = 3.642153, Time = 296.86s
# Test Loss = 4.005854, Accuracy = 11.50%
# ------------------------------------------------------------
# Epoch 74/100: Train Loss = 3.635968, Time = 296.70s
# Test Loss = 4.092994, Accuracy = 10.27%
# ------------------------------------------------------------
# Epoch 75/100: Train Loss = 3.614065, Time = 296.83s
# Test Loss = 3.985898, Accuracy = 11.70%
# ------------------------------------------------------------
# Epoch 76/100: Train Loss = 3.612354, Time = 297.09s
# Test Loss = 4.032678, Accuracy = 10.55%
# ------------------------------------------------------------
# Epoch 77/100: Train Loss = 3.562174, Time = 297.26s
# Test Loss = 4.076207, Accuracy = 10.07%
# ------------------------------------------------------------
# Epoch 78/100: Train Loss = 3.546030, Time = 297.58s
# Test Loss = 3.943023, Accuracy = 12.42%
# ------------------------------------------------------------
# Epoch 79/100: Train Loss = 3.534280, Time = 297.87s
# Test Loss = 3.966142, Accuracy = 11.65%
# ------------------------------------------------------------
# Epoch 80/100: Train Loss = 3.506048, Time = 296.25s
# Test Loss = 3.907846, Accuracy = 12.40%
# ------------------------------------------------------------
# Epoch 81/100: Train Loss = 3.462140, Time = 296.92s
# Test Loss = 3.932476, Accuracy = 12.18%
# ------------------------------------------------------------
# Epoch 82/100: Train Loss = 3.468819, Time = 296.04s
# Test Loss = 4.012154, Accuracy = 11.02%
# ------------------------------------------------------------
# Epoch 83/100: Train Loss = 3.444306, Time = 296.75s
# Test Loss = 3.919407, Accuracy = 12.52%
# ------------------------------------------------------------
# Epoch 84/100: Train Loss = 3.444286, Time = 296.32s
# Test Loss = 3.875285, Accuracy = 13.23%
# ------------------------------------------------------------
# Epoch 85/100: Train Loss = 3.380584, Time = 297.28s
# Test Loss = 3.838364, Accuracy = 14.07%
# ------------------------------------------------------------
# Epoch 86/100: Train Loss = 3.374446, Time = 297.28s
# Test Loss = 3.897590, Accuracy = 12.20%
# ------------------------------------------------------------
# Epoch 87/100: Train Loss = 3.355765, Time = 297.27s
# Test Loss = 3.909834, Accuracy = 12.76%
# ------------------------------------------------------------
# Epoch 88/100: Train Loss = 3.347198, Time = 296.79s
# Test Loss = 3.825658, Accuracy = 13.68%
# ------------------------------------------------------------
# Epoch 89/100: Train Loss = 3.324808, Time = 297.11s
# Test Loss = 3.835224, Accuracy = 13.44%
# ------------------------------------------------------------
# Epoch 90/100: Train Loss = 3.319731, Time = 297.75s
# Test Loss = 3.946834, Accuracy = 11.95%
# ------------------------------------------------------------
# Epoch 91/100: Train Loss = 3.281347, Time = 296.69s
# Test Loss = 3.761196, Accuracy = 14.21%
# ------------------------------------------------------------
# Epoch 92/100: Train Loss = 3.269686, Time = 296.41s
# Test Loss = 3.770151, Accuracy = 14.10%
# ------------------------------------------------------------
# Epoch 93/100: Train Loss = 3.243044, Time = 296.51s
# Test Loss = 3.818251, Accuracy = 13.28%
# ------------------------------------------------------------
# Epoch 94/100: Train Loss = 3.217413, Time = 296.27s
# Test Loss = 3.800986, Accuracy = 13.01%
# ------------------------------------------------------------
# Epoch 95/100: Train Loss = 3.210314, Time = 297.04s
# Test Loss = 3.744788, Accuracy = 14.49%
# ------------------------------------------------------------
# Epoch 96/100: Train Loss = 3.172674, Time = 296.40s
# Test Loss = 3.826721, Accuracy = 13.33%
# ------------------------------------------------------------
# Epoch 97/100: Train Loss = 3.161699, Time = 296.13s
# Test Loss = 3.724254, Accuracy = 14.95%
# ------------------------------------------------------------
# Epoch 98/100: Train Loss = 3.160390, Time = 296.53s
# Test Loss = 3.752893, Accuracy = 14.28%
# ------------------------------------------------------------
# Epoch 99/100: Train Loss = 3.136933, Time = 296.34s
# Test Loss = 3.739613, Accuracy = 14.38%
# ------------------------------------------------------------
# Epoch 100/100: Train Loss = 3.102063, Time = 296.52s
# Test Loss = 3.740941, Accuracy = 14.30%
# ------------------------------------------------------------
# End-to-End CNN model training completed and saved!
# Model deleted and GPU memory cleared.
